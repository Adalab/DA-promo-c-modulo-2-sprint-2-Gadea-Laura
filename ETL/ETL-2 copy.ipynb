# %% [markdown]
# # ETL 2. Transformación 1 - Limpieza

# %%
from IPython.core.interactiveshell import InteractiveShell # Nos permite mostar más de una salida por celda
InteractiveShell.ast_node_interactivity = "all" # Nos permite mostar más de una salida por celda

import requests
import pandas as pd
import numpy as np
import ast 

from datetime import datetime, timedelta

pd.options.display.max_columns=None

# %% [markdown]
# ## Introducción:
# Tendréis que usar el csv attacks_limpieza_completa que tenéis adjunto abajo.
# En la lección de hoy aprendimos como transformar nuestros datos para que estén preparados para almacearlos en una BBDD. En este momento tenemos dos fuentes de datos:
#
# - El csv con los ataques de tiburones que hemos estado limpiando hasta ahora, el que os hemos adjuntado (attacks_limpieza_completa). Sentiros libres de usar vuestros propios csv en caso de que queráis.
# - El csv con los datos climáticos de los principales paises que tienen ataques de tiburones, el que creamos en el pair programming de ayer.
#
# **El objetivo de la sesión de hoy será juntar en un único csv la información de ambas fuentes**.
#
# Para ello:
# 1. Cargaremos los dos ficheros de datos del dataframe de los ataques nos quedaremos solo con las filas de los países que seleccionamos en la lección de ayer:
#     - USA
#     - Australia
#     - New Zealand
#     - South Africa
#     - Papua New Guinea

# %%
clima = pd.read_csv('datos/ETL-1.csv', index_col = 0)
clima.head(2)
# Out:
#    timepoint  cloudcover  highcloud  midcloud  lowcloud  \
# 0          3           1      -9999     -9999     -9999
# 1          6           1      -9999     -9999     -9999
#
#                                           rh_profile  \
# 0  [{'layer': '950mb', 'rh': 1}, {'layer': '900mb...
# 1  [{'layer': '950mb', 'rh': 1}, {'layer': '900mb...
#
#                                         wind_profile  temp2m  lifted_index  \
# 0  [{'layer': '950mb', 'direction': 40, 'speed': ...      12            15
# 1  [{'layer': '950mb', 'direction': 325, 'speed':...      14            15
#
#    rh2m  msl_pressure prec_type  prec_amount  snow_depth  wind10m.direction  \
# 0     2          1028      none            0           0                315
# 1     1          1027      none            0           0                 50
#
#    wind10m.speed country
# 0              2     USA
# 1              2     USA

# %%
df = pd.read_csv('datos/attacks_limpieza_completa.csv', index_col=0)
df.head(2)
# Out:
#    year        type country   age     species_ fecha_limpia fatal sex  \
# 0  2018     Boating     usa  57.0  White shark          Jun     N   F
# 1  2018  Unprovoked     usa  11.0  Unespecific          Jun     N   F
#
#     latitud    longitud country2  fatal_N  fatal_Unknown  fatal_Y  fatal_N.1  \
# 0  39.78373 -100.445882       HN        1              0        0          1
# 1  39.78373 -100.445882       HN        1              0        0          1
#
#    fatal_Unknown.1  fatal_Y.1  species_.1  fecha_limpia.1  type.1  age_NORM
# 0                0          0           4               7       1  9.116327
# 1                0          0           3               7       7  3.804860

# %% [markdown]
# ### Nos quedamos con los países que nos piden:

# %%
list_country = ['usa', 'australia', 'south africa', 'new zealand', 'papua new guinea']

# %%
df_country = df[df['country'].isin(list_country)]
df_country.head()
# Out:
#    year        type    country   age     species_ fecha_limpia fatal sex  \
# 0  2018     Boating        usa  57.0  White shark          Jun     N   F
# 1  2018  Unprovoked        usa  11.0  Unespecific          Jun     N   F
# 2  2018     Invalid        usa  48.0  Unespecific          Jun     N   M
# 3  2018  Unprovoked  australia  27.0  Unespecific          Jun     N   M
# 5  2018  Unprovoked  australia  27.0  Unespecific          Jun     N   M
#
#      latitud    longitud country2  fatal_N  fatal_Unknown  fatal_Y  fatal_N.1  \
# 0  39.783730 -100.445882       HN        1              0        0          1
# 1  39.783730 -100.445882       HN        1              0        0          1
# 2  39.783730 -100.445882       HN        1              0        0          1
# 3 -24.776109  134.755000       HS        1              0        0          1
# 5 -24.776109  134.755000       HS        1              0        0          1
#
#    fatal_Unknown.1  fatal_Y.1  species_.1  fecha_limpia.1  type.1  age_NORM
# 0                0          0           4               7       1  9.116327
# 1                0          0           3               7       7  3.804860
# 2                0          0           3               7       3  8.403629
# 3                0          0           3               7       7  6.313925
# 5                0          0           3               7       7  6.313925

# %%
df_country['country'].unique()
# Out:
# array(['usa', 'australia', 'south africa', 'new zealand',
#        'papua new guinea'], dtype=object)

# %% [markdown]
# ### Desempaquetamos la columna 'hr_profile':

# %%
clima['rh_profile'] = clima['rh_profile'].apply(ast.literal_eval)

# %%
df_rh = clima['rh_profile'].apply(pd.Series)

# %%
df_rh.head(2)
# Out:
#                             0                            1   \
# 0  {'layer': '950mb', 'rh': 1}  {'layer': '900mb', 'rh': 1}
# 1  {'layer': '950mb', 'rh': 1}  {'layer': '900mb', 'rh': 2}
#
#                             2                            3   \
# 0  {'layer': '850mb', 'rh': 4}  {'layer': '800mb', 'rh': 6}
# 1  {'layer': '850mb', 'rh': 5}  {'layer': '800mb', 'rh': 6}
#
#                             4                            5   \
# 0  {'layer': '750mb', 'rh': 6}  {'layer': '700mb', 'rh': 6}
# 1  {'layer': '750mb', 'rh': 4}  {'layer': '700mb', 'rh': 3}
#
#                             6                            7   \
# 0  {'layer': '650mb', 'rh': 7}  {'layer': '600mb', 'rh': 8}
# 1  {'layer': '650mb', 'rh': 4}  {'layer': '600mb', 'rh': 5}
#
#                             8                            9   \
# 0  {'layer': '550mb', 'rh': 5}  {'layer': '500mb', 'rh': 3}
# 1  {'layer': '550mb', 'rh': 6}  {'layer': '500mb', 'rh': 5}
#
#                             10                            11  \
# 0  {'layer': '450mb', 'rh': 1}  {'layer': '400mb', 'rh': -1}
# 1  {'layer': '450mb', 'rh': 2}  {'layer': '400mb', 'rh': -1}
#
#                             12                           13  \
# 0  {'layer': '350mb', 'rh': 1}  {'layer': '300mb', 'rh': 2}
# 1  {'layer': '350mb', 'rh': 3}  {'layer': '300mb', 'rh': 5}
#
#                             14                           15
# 0  {'layer': '250mb', 'rh': 6}  {'layer': '200mb', 'rh': 6}
# 1  {'layer': '250mb', 'rh': 0}  {'layer': '200mb', 'rh': 3}

# %%
for i in range(len(df_rh.columns)):
    nombre_rh = "rh_"+ str(df_rh[i].apply(pd.Series)["layer"][0])
    valores_rh = (df_rh[i].apply(pd.Series)["rh"])

    clima.insert(i, nombre_rh, valores_rh)

# %%
clima.head()
# Out:
#    rh_950mb  rh_900mb  rh_850mb  rh_800mb  rh_750mb  rh_700mb  rh_650mb  \
# 0         1         1         4         6         6         6         7
# 1         1         2         5         6         4         3         4
# 2         1         4         5         5         2         2         2
# 3         3         4         5         4         2         1         1
# 4         4         4         4         3         2         1         0
#
#    rh_600mb  rh_550mb  rh_500mb  rh_450mb  rh_400mb  rh_350mb  rh_300mb  \
# 0         8         5         3         1        -1         1         2
# 1         5         6         5         2        -1         3         5
# 2         3         4         5         6         4         3         1
# 3         2         1         2         4         6         5         5
# 4         0         0         0         4         4        11        12
#
#    rh_250mb  rh_200mb  timepoint  cloudcover  highcloud  midcloud  lowcloud  \
# 0         6         6          3           1      -9999     -9999     -9999
# 1         0         3          6           1      -9999     -9999     -9999
# 2         1         5          9           1      -9999     -9999     -9999
# 3         4         3         12           1      -9999     -9999     -9999
# 4         9         6         15           1      -9999     -9999     -9999
#
#                                           rh_profile  \
# 0  [{'layer': '950mb', 'rh': 1}, {'layer': '900mb...
# 1  [{'layer': '950mb', 'rh': 1}, {'layer': '900mb...
# 2  [{'layer': '950mb', 'rh': 1}, {'layer': '900mb...
# 3  [{'layer': '950mb', 'rh': 3}, {'layer': '900mb...
# 4  [{'layer': '950mb', 'rh': 4}, {'layer': '900mb...
#
#                                         wind_profile  temp2m  lifted_index  \
# 0  [{'layer': '950mb', 'direction': 40, 'speed': ...      12            15
# 1  [{'layer': '950mb', 'direction': 325, 'speed':...      14            15
# 2  [{'layer': '950mb', 'direction': 190, 'speed':...      14            15
# 3  [{'layer': '950mb', 'direction': 235, 'speed':...      13            10
# 4  [{'layer': '950mb', 'direction': 215, 'speed':...      13            15
#
#    rh2m  msl_pressure prec_type  prec_amount  snow_depth  wind10m.direction  \
# 0     2          1028      none            0           0                315
# 1     1          1027      none            0           0                 50
# 2     3          1026      none            0           0                 85
# 3     8          1026      none            0           0                 30
# 4     8          1027      none            0           0                  5
#
#    wind10m.speed country
# 0              2     USA
# 1              2     USA
# 2              2     USA
# 3              2     USA
# 4              2     USA

# %% [markdown]
# ### Desempaquetamos la columna 'wind_profile':

# %%
clima['wind_profile'] = clima['wind_profile'].apply(ast.literal_eval)

# %%
df_wind = clima['wind_profile'].apply(pd.Series)
df_wind.head(2)
# Out:
#                                                  0   \
# 0   {'layer': '950mb', 'direction': 40, 'speed': 1}
# 1  {'layer': '950mb', 'direction': 325, 'speed': 2}
#
#                                                  1   \
# 0    {'layer': '900mb', 'direction': 5, 'speed': 3}
# 1  {'layer': '900mb', 'direction': 310, 'speed': 2}
#
#                                                  2   \
# 0  {'layer': '850mb', 'direction': 335, 'speed': 3}
# 1  {'layer': '850mb', 'direction': 305, 'speed': 3}
#
#                                                  3   \
# 0  {'layer': '800mb', 'direction': 335, 'speed': 4}
# 1  {'layer': '800mb', 'direction': 320, 'speed': 4}
#
#                                                  4   \
# 0  {'layer': '750mb', 'direction': 325, 'speed': 4}
# 1  {'layer': '750mb', 'direction': 320, 'speed': 4}
#
#                                                  5   \
# 0  {'layer': '700mb', 'direction': 325, 'speed': 4}
# 1  {'layer': '700mb', 'direction': 325, 'speed': 4}
#
#                                                  6   \
# 0  {'layer': '650mb', 'direction': 330, 'speed': 5}
# 1  {'layer': '650mb', 'direction': 330, 'speed': 5}
#
#                                                  7   \
# 0  {'layer': '600mb', 'direction': 325, 'speed': 5}
# 1  {'layer': '600mb', 'direction': 330, 'speed': 5}
#
#                                                  8   \
# 0  {'layer': '550mb', 'direction': 315, 'speed': 5}
# 1  {'layer': '550mb', 'direction': 325, 'speed': 5}
#
#                                                  9   \
# 0  {'layer': '500mb', 'direction': 320, 'speed': 6}
# 1  {'layer': '500mb', 'direction': 325, 'speed': 5}
#
#                                                  10  \
# 0  {'layer': '450mb', 'direction': 325, 'speed': 6}
# 1  {'layer': '450mb', 'direction': 320, 'speed': 5}
#
#                                                  11  \
# 0  {'layer': '400mb', 'direction': 320, 'speed': 6}
# 1  {'layer': '400mb', 'direction': 315, 'speed': 5}
#
#                                                  12  \
# 0  {'layer': '350mb', 'direction': 325, 'speed': 6}
# 1  {'layer': '350mb', 'direction': 305, 'speed': 5}
#
#                                                  13  \
# 0  {'layer': '300mb', 'direction': 330, 'speed': 6}
# 1  {'layer': '300mb', 'direction': 305, 'speed': 6}
#
#                                                  14  \
# 0  {'layer': '250mb', 'direction': 330, 'speed': 7}
# 1  {'layer': '250mb', 'direction': 320, 'speed': 6}
#
#                                                  15
# 0  {'layer': '200mb', 'direction': 345, 'speed': 7}
# 1  {'layer': '200mb', 'direction': 330, 'speed': 6}

# %%
for i in range(len(df_wind.columns)): 

    nombre = "wind_direction_" + str(df_wind[i].apply(pd.Series)["layer"][0]) 

    valores = list(df_wind[i].apply(pd.Series)["direction"])

    clima.insert(i, nombre, valores)

# %%
clima.head()
# Out:
#    wind_direction_950mb  wind_direction_900mb  wind_direction_850mb  \
# 0                    40                     5                   335
# 1                   325                   310                   305
# 2                   190                   270                   295
# 3                   235                   250                   285
# 4                   215                   250                   275
#
#    wind_direction_800mb  wind_direction_750mb  wind_direction_700mb  \
# 0                   335                   325                   325
# 1                   320                   320                   325
# 2                   310                   310                   315
# 3                   305                   305                   310
# 4                   290                   295                   295
#
#    wind_direction_650mb  wind_direction_600mb  wind_direction_550mb  \
# 0                   330                   325                   315
# 1                   330                   330                   325
# 2                   315                   315                   325
# 3                   315                   315                   310
# 4                   295                   300                   305
#
#    wind_direction_500mb  wind_direction_450mb  wind_direction_400mb  \
# 0                   320                   325                   320
# 1                   325                   320                   315
# 2                   325                   325                   320
# 3                   315                   310                   305
# 4                   305                   310                   305
#
#    wind_direction_350mb  wind_direction_300mb  wind_direction_250mb  \
# 0                   325                   330                   330
# 1                   305                   305                   320
# 2                   315                   305                   300
# 3                   295                   300                   315
# 4                   310                   305                   305
#
#    wind_direction_200mb  rh_950mb  rh_900mb  rh_850mb  rh_800mb  rh_750mb  \
# 0                   345         1         1         4         6         6
# 1                   330         1         2         5         6         4
# 2                   315         1         4         5         5         2
# 3                   325         3         4         5         4         2
# 4                   310         4         4         4         3         2
#
#    rh_700mb  rh_650mb  rh_600mb  rh_550mb  rh_500mb  rh_450mb  rh_400mb  \
# 0         6         7         8         5         3         1        -1
# 1         3         4         5         6         5         2        -1
# 2         2         2         3         4         5         6         4
# 3         1         1         2         1         2         4         6
# 4         1         0         0         0         0         4         4
#
#    rh_350mb  rh_300mb  rh_250mb  rh_200mb  timepoint  cloudcover  highcloud  \
# 0         1         2         6         6          3           1      -9999
# 1         3         5         0         3          6           1      -9999
# 2         3         1         1         5          9           1      -9999
# 3         5         5         4         3         12           1      -9999
# 4        11        12         9         6         15           1      -9999
#
#    midcloud  lowcloud                                         rh_profile  \
# 0     -9999     -9999  [{'layer': '950mb', 'rh': 1}, {'layer': '900mb...
# 1     -9999     -9999  [{'layer': '950mb', 'rh': 1}, {'layer': '900mb...
# 2     -9999     -9999  [{'layer': '950mb', 'rh': 1}, {'layer': '900mb...
# 3     -9999     -9999  [{'layer': '950mb', 'rh': 3}, {'layer': '900mb...
# 4     -9999     -9999  [{'layer': '950mb', 'rh': 4}, {'layer': '900mb...
#
#                                         wind_profile  temp2m  lifted_index  \
# 0  [{'layer': '950mb', 'direction': 40, 'speed': ...      12            15
# 1  [{'layer': '950mb', 'direction': 325, 'speed':...      14            15
# 2  [{'layer': '950mb', 'direction': 190, 'speed':...      14            15
# 3  [{'layer': '950mb', 'direction': 235, 'speed':...      13            10
# 4  [{'layer': '950mb', 'direction': 215, 'speed':...      13            15
#
#    rh2m  msl_pressure prec_type  prec_amount  snow_depth  wind10m.direction  \
# 0     2          1028      none            0           0                315
# 1     1          1027      none            0           0                 50
# 2     3          1026      none            0           0                 85
# 3     8          1026      none            0           0                 30
# 4     8          1027      none            0           0                  5
#
#    wind10m.speed country
# 0              2     USA
# 1              2     USA
# 2              2     USA
# 3              2     USA
# 4              2     USA

# %%
for i in range(len(df_wind.columns)): 

    nombre = "wind_speed_" + str(df_wind[i].apply(pd.Series)["layer"][0]) 

    valores = list(df_wind[i].apply(pd.Series)["speed"])

    clima.insert(i, nombre, valores)

# %%
clima.head()
# Out:
#    wind_speed_950mb  wind_speed_900mb  wind_speed_850mb  wind_speed_800mb  \
# 0                 1                 3                 3                 4
# 1                 2                 2                 3                 4
# 2                 2                 3                 3                 4
# 3                 2                 3                 3                 4
# 4                 2                 3                 3                 3
#
#    wind_speed_750mb  wind_speed_700mb  wind_speed_650mb  wind_speed_600mb  \
# 0                 4                 4                 5                 5
# 1                 4                 4                 5                 5
# 2                 4                 4                 4                 5
# 3                 4                 4                 4                 4
# 4                 3                 4                 4                 4
#
#    wind_speed_550mb  wind_speed_500mb  wind_speed_450mb  wind_speed_400mb  \
# 0                 5                 6                 6                 6
# 1                 5                 5                 5                 5
# 2                 5                 5                 5                 5
# 3                 5                 5                 5                 5
# 4                 5                 5                 5                 5
#
#    wind_speed_350mb  wind_speed_300mb  wind_speed_250mb  wind_speed_200mb  \
# 0                 6                 6                 7                 7
# 1                 5                 6                 6                 6
# 2                 5                 5                 5                 6
# 3                 5                 5                 5                 5
# 4                 5                 5                 5                 5
#
#    wind_direction_950mb  wind_direction_900mb  wind_direction_850mb  \
# 0                    40                     5                   335
# 1                   325                   310                   305
# 2                   190                   270                   295
# 3                   235                   250                   285
# 4                   215                   250                   275
#
#    wind_direction_800mb  wind_direction_750mb  wind_direction_700mb  \
# 0                   335                   325                   325
# 1                   320                   320                   325
# 2                   310                   310                   315
# 3                   305                   305                   310
# 4                   290                   295                   295
#
#    wind_direction_650mb  wind_direction_600mb  wind_direction_550mb  \
# 0                   330                   325                   315
# 1                   330                   330                   325
# 2                   315                   315                   325
# 3                   315                   315                   310
# 4                   295                   300                   305
#
#    wind_direction_500mb  wind_direction_450mb  wind_direction_400mb  \
# 0                   320                   325                   320
# 1                   325                   320                   315
# 2                   325                   325                   320
# 3                   315                   310                   305
# 4                   305                   310                   305
#
#    wind_direction_350mb  wind_direction_300mb  wind_direction_250mb  \
# 0                   325                   330                   330
# 1                   305                   305                   320
# 2                   315                   305                   300
# 3                   295                   300                   315
# 4                   310                   305                   305
#
#    wind_direction_200mb  rh_950mb  rh_900mb  rh_850mb  rh_800mb  rh_750mb  \
# 0                   345         1         1         4         6         6
# 1                   330         1         2         5         6         4
# 2                   315         1         4         5         5         2
# 3                   325         3         4         5         4         2
# 4                   310         4         4         4         3         2
#
#    rh_700mb  rh_650mb  rh_600mb  rh_550mb  rh_500mb  rh_450mb  rh_400mb  \
# 0         6         7         8         5         3         1        -1
# 1         3         4         5         6         5         2        -1
# 2         2         2         3         4         5         6         4
# 3         1         1         2         1         2         4         6
# 4         1         0         0         0         0         4         4
#
#    rh_350mb  rh_300mb  rh_250mb  rh_200mb  timepoint  cloudcover  highcloud  \
# 0         1         2         6         6          3           1      -9999
# 1         3         5         0         3          6           1      -9999
# 2         3         1         1         5          9           1      -9999
# 3         5         5         4         3         12           1      -9999
# 4        11        12         9         6         15           1      -9999
#
#    midcloud  lowcloud                                         rh_profile  \
# 0     -9999     -9999  [{'layer': '950mb', 'rh': 1}, {'layer': '900mb...
# 1     -9999     -9999  [{'layer': '950mb', 'rh': 1}, {'layer': '900mb...
# 2     -9999     -9999  [{'layer': '950mb', 'rh': 1}, {'layer': '900mb...
# 3     -9999     -9999  [{'layer': '950mb', 'rh': 3}, {'layer': '900mb...
# 4     -9999     -9999  [{'layer': '950mb', 'rh': 4}, {'layer': '900mb...
#
#                                         wind_profile  temp2m  lifted_index  \
# 0  [{'layer': '950mb', 'direction': 40, 'speed': ...      12            15
# 1  [{'layer': '950mb', 'direction': 325, 'speed':...      14            15
# 2  [{'layer': '950mb', 'direction': 190, 'speed':...      14            15
# 3  [{'layer': '950mb', 'direction': 235, 'speed':...      13            10
# 4  [{'layer': '950mb', 'direction': 215, 'speed':...      13            15
#
#    rh2m  msl_pressure prec_type  prec_amount  snow_depth  wind10m.direction  \
# 0     2          1028      none            0           0                315
# 1     1          1027      none            0           0                 50
# 2     3          1026      none            0           0                 85
# 3     8          1026      none            0           0                 30
# 4     8          1027      none            0           0                  5
#
#    wind10m.speed country
# 0              2     USA
# 1              2     USA
# 2              2     USA
# 3              2     USA
# 4              2     USA

# %% [markdown]
# 4. Guardad los resultados obtenidos en un csv que usaremos en próximos ejercicios de pair programming.
